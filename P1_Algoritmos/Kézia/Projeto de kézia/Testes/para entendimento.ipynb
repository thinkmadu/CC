# %%
import numpy as np
n = 4
matriz1 = np.arange(6)
matriz1 = matriz1.reshape(2,3)
matriz2 = np.zeros_like(matriz1)

print(matriz1)
print(matriz2)
# Out:
# [[0 1 2]
#  [3 4 5]]
# [[0 0 0]
#  [0 0 0]]
