# %% [markdown]
# Algoritmo: sequênica de passos lógicos, finitos que tem uma entrada e saída.
# - depende de fatores internos (sistema, hardware, rede) e externos (situação, cenário, demanda).
# - tempo de execução e espaço de entrada () são parâmetros de avaliação que levam a decisão dos melhor algoritmo.
# - o espaço de entrada está diretamente relacionado ao tempo de execução: quanto maior o código, maior sera o espaço.
# - complexidade computacional.
# - complexidade assintótica.
# - np completo: problemas que não possuem respostas até hoje.
# # np completo dos neurônios no japão.
#
# ESTRUTURA DE DADOS: é organização acumulada de dados que foram inseridos.
# SELECTION.SORT(): organiza a lista começando a comparar a partir do 2º elemento
# - Ele olha o elemento da posição 1 (elemento 2), compara com a anterior: se for maior, fica naquela posição, se for menor, ele volta uma posição.
# # recursividade
