# %%
#lista[inicio:fim:passo]

lista = [1,2,3,4,5,6]
print(lista[:-1:2])
print(lista[5:0:-1])
print(lista[::-1])
# Out:
# [1, 3, 5]
# [6, 5, 4, 3, 2]
# [6, 5, 4, 3, 2, 1]

# %%
lista = [1,2,3,4,5,6]

del lista[0]

print(lista)

del lista[7]
# Out:
# [2, 3, 4, 5, 6]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-7b41d7ebefbc> in <module>
#       5 print(lista)
#       6
# ----> 7 del lista[7]
#
# IndexError: list assignment index out of range

# %%
lista = [1,2,3,4,5]

print(max(lista))
print(min(lista))

lista1 = ["a","f","z","b"]
print(max(lista1))
print(min(lista1))

lista2 = [1,1,1,1]
print(max(lista2))
print(min(lista2))

lista1 = ["a","ab","ze","z"]
print(max(lista1))
print(min(lista1))


print(max([1,'z']))
# Out:
# 5
# 1
# z
# a
# 1
# 1
# ze
# a
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-92800ecd9aa2> in <module>
#      17
#      18
# ---> 19 print(max([1,'z']))
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
lista1 = [1,2,3]
lista2 = [1,2,3]

if lista1 == lista2:
    print("são iguais")
else:
    print("nao")
    
lista1 = [1,2,3]
lista2 = [2,1,3]

if lista1 == lista2:
    print("são iguais")
else:
    print("nao")
# Out:
# são iguais
# nao

# %%
lista1 = [1,2,3]
lista2 = lista1

lista1[0] = 10
print(lista1)
print(lista2)

lista3 = lista1[:]

lista1[0] = 12

print(lista1)
print(lista3)


print(lista2 is lista1)
print(lista3 is lista1)
# Out:
# [10, 2, 3]
# [10, 2, 3]
# [12, 2, 3]
# [10, 2, 3]
# True
# False

# %%
lista = []
lista.append(2)

print(lista)

lista.append(4)
print(lista)
# Out:
# [2]
# [2, 4]

# %%
lista1 = [1,2,3]
lista2 = [4,5,6]

lista1.extend(lista2)
print(lista1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
lista= [1,3,4]
lista.insert(4,2)
print(lista)

lista.insert(10,20)
print(lista)
# Out:
# [1, 3, 4, 2]
# [1, 3, 4, 2, 20]

# %%
lista = [1,2,3,2]
lista.remove(2)
print(lista)

lista.remove(3)
# Out:
# [1, 3, 2]

# %%
lista = [1,2,3]
lista.pop(0)
print(lista)

lista.pop()
print(lista)
# Out:
# [2, 3]
# [2]

# %%
lista = [1,2,3]
lista.clear()
print(lista)
# Out:
# []

# %%
lista = [1,2,1,3,4]
print(lista.count(1))
# Out:
# 2

# %%
lista = [1,2,1,3,4]
print(lista.index(1))

print(lista.index(2))
# Out:
# 0
# 1

# %%
lista = [2,5,2,7]
lista.reverse()
print(lista)
# Out:
# [7, 2, 5, 2]

# %%
lista1 = [1,2,3]
lista2 = lista1.copy()

print(lista2)

print(lista2 is lista1)
# Out:
# [1, 2, 3]
# False

# %%
#sort(key=None, reverse=False)

lista = [1,6,-3,0,34,-9]
lista.sort()
print(lista)

lista1 = ["abc","de","a"]
lista1.sort()
print(lista1)

lista = [1,6,-3,0,34,-9]
lista.sort(reverse=True)
print(lista)


lista1 = ["abc","de","a"]
lista1.sort(key=len)
print(lista1)
# Out:
# [-9, -3, 0, 1, 6, 34]
# ['a', 'abc', 'de']
# [34, 6, 1, 0, -3, -9]
# ['a', 'de', 'abc']
