# %%
print("Alô Mundo")
# Out:
# Alô Mundo

# %%
print('Alô Mundo')
# Out:
# Alô Mundo

# %%
print"Alo Mundo")
# Out:
#   File "<ipython-input-3-517a81a6f1c5>", line 1
#     print"Alo Mundo")
#                    ^
# SyntaxError: invalid syntax

# %%
print(Alo mundo)
# Out:
#   File "<ipython-input-7-ebb179860f62>", line 1
#     print(Alo mundo)
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# Os tipos básicos em Python são:
# • int – um número inteiro
# • float –um número em ponto flutuante
# • string - sequência de caracteres delimitadas por aspas simples ou duplas
#
# Números complexos: real + imag j. Exemplo: 2 + 3j

# %%
print(3,"a")
print(4.9)
print(3 + 4j)
# Out:
# 3 a
# 4.9
# (3+4j)

# %%
msg = "Alo mundo"
idade = 4
altura = 1.8

# %%
print(msg)
print(idade)
print(altura)
# Out:
# Alo mundo
# 4
# 1.8

# %%
print(type(msg))
print(type(idade))
print(type(altura))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
nomeAluno = "kezia"

# %%
1nome = "kezia"
# Out:
#   File "<ipython-input-5-ae556f3d2d9b>", line 1
#     1nome = "kezia"
#         ^
# SyntaxError: invalid syntax

# %%
$nome = "kezia"
# Out:
#   File "<ipython-input-10-06a2f6c004be>", line 1
#     $nome = "kezia"
#     ^
# SyntaxError: invalid syntax

# %%
a = 3
b = 3.2

# %%
control = True
print(control)

control2 = False
print(control2)
# Out:
# True
# False

# %%
entrada = input()
print(entrada)
# Out:
# kezia
# kezia

# %%
entrada = input("Digite um nome:")
# Out:
# Digite um nome:kezia

# %%
entrada = input("Digite um nome:")
print("O nome informado foi:", entrada)
print("O nome informado foi:"+ entrada)
# Out:
# Digite um nome:kezia
# O nome informado foi: kezia
# O nome informado foi:kezia

# %%
entrada = int(input("Digite um numero:"))
print(entrada)
# Out:
# Digite um numero:q
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-a456580bfc6e> in <module>()
# ----> 1 entrada = int(input("Digite um numero:"))
#       2 print(entrada)
#
# ValueError: invalid literal for int() with base 10: 'q'

# %%
entrada = int(input("Digite um numero:"))
print(type(entrada))
# Out:
# <class 'int'>
