# %%
a = 1
b = 2
c = 3.0
d = 4.0

# %%
soma = a + b
print("soma:", soma)

soma1 = c + d
print("soma:", soma1)

soma2 = a + d
print("soma:", soma2)
# Out:
# soma: 3
# soma: 7.0
# soma: 5.0

# %%
diferenca = a - b
print("diferenca:", diferenca)

diferenca1 = c - d
print("diferenca:", diferenca1)

diferenca2 = a - d
print("diferenca:", diferenca2)
# Out:
# diferenca: -1
# diferenca: -1.0
# diferenca: -3.0

# %%
mult= a * b
print("mult:", mult)

mult1 = c * d
print("mult:", mult1)

mult2 = a * d
print("mult:", mult2)
# Out:
# mult: 2
# mult: 12.0
# mult: 4.0

# %%
divi= a / a
print("divi:", divi)

divi1 = c / d
print("divi:", divi1)

divi2 = a / d
print("divi:", divi2)
# Out:
# divi: 1.0
# divi: 0.75
# divi: 0.25

# %%
a = 7
b = 2

#isso daqui pega a parte inteira da divisão
q = a // b
print("q:", q)

#isso daqui pega o resto da divisõa feita
resto = a % b
print("resto", resto)
# Out:
# q: 3
# resto 1

# %%
potencia = a ** b
print("potencia", potencia)
# Out:
# potencia 1
