# %%
# os inputs das linhas vão ser separadas por espaços.
# matriz = [[0,0,0],[0,1,0],[1,1,1]]
# matriz = [[1,5,8],[4,1,6],[5,1,1]]
# matriz = [[0]]
matriz = list()

def numIguais(lista):
    for i in lista:
        if i != 0:
            return False
        else:
            return True


def determinanteNulo(matriz):
    colunasMatriz = list()

    for linhas in matriz:
        if numIguais(linhas):
            return True
        
    for index in range(len(matriz[0])):
        listaTemp = list()

        for linhas in matriz:
            listaTemp.append(linhas[index])
        
        colunasMatriz.append(listaTemp)
        listaTemp = list()
    
    for matriz in colunasMatriz:
        if numIguais(matriz):
            return True


if len(matriz) <= 0:
        print('Pô Kézia! A dimensão da matriz precisa ser um inteiro maior que 0!!!')

else:
    if determinanteNulo(matriz):
        print('Essa matriz tem determinante nulo :))')
    else:
        print('Essa matriz não tem determinante nulo >>:((')
# Out:
# Pô Kézia! A dimensão da matriz precisa ser um inteiro maior que 0!!!

# %%
# os inputs das linhas vão ser separadas por espaços.
# matriz = [[0,0,0],[0,1,0],[1,1,1]]
# matriz = [[1,5,8],[4,1,6],[5,1,1]]
# matriz = [[0,1],[0,1]]
# matriz = [[0]]
# matriz = list()
# matriz = [[5,2],[7]]

def numIguais(lista):
    for i in lista:
        if i != 0:
            return False
        else:
            return True


def determinanteNulo(matriz):
    colunasMatriz = list()

    for linhas in matriz:
        if numIguais(linhas):
            return True
        
    for index in range(len(matriz[0])):
        listaTemp = list()

        for linhas in matriz:
            listaTemp.append(linhas[index])
        
        colunasMatriz.append(listaTemp)
        listaTemp = list()
    
    for matriz in colunasMatriz:
        if numIguais(matriz):
            return True

try:
    if len(matriz) <= 0:
            print('Pô Kézia! A dimensão da matriz precisa ser um inteiro maior que 0!!!')

    else:
        if determinanteNulo(matriz):
            print('Essa matriz tem determinante nulo :))')
        else:
            print('Essa matriz não tem determinante nulo >>:((')

except IndexError:
    print('Ei, pode não. A matriz não é quadrada, não dá pra achar determinante.')

# %%
# os inputs das linhas vão ser separadas por espaços.

def geradorMatriz(tamanho):
    matriz = list()

    for index, linha in enumerate(range(tamanho)):
        elementosLinha = list(map(int, input('Digite os elementos da {}ª linha: '.format(index + 1)).strip().split()))

    if len(elementosLinha) != tamanhoMatriz:
        print('A quantidade de nº informados não é compatível com a dimensão da matriz selecionada :///')
        
    matriz.append(elementosLinha)

    return matriz


def numIguais(lista):
    for i in lista:
        if i != 0:
            return False
        else:
            return True


def determinanteNulo(matriz):
    colunasMatriz = list()

    for linhas in matriz:
        if numIguais(linhas):
            return True
        
    for index in range(len(matriz[0])):
        listaTemp = list()

        for linhas in matriz:
            listaTemp.append(linhas[index])
        
        colunasMatriz.append(listaTemp)
        listaTemp = list()
    
    for matriz in colunasMatriz:
        if numIguais(matriz):
            return True


tamanhoMatriz = int(input('Digite a dimensão da matriz: '))

if tamanhoMatriz <= 0:
    if geradorMatriz == True:
        print('Pô Kézia! A dimensão da matriz precisa ser um inteiro maior que 0!!!')   

else:
    matriz = geradorMatriz(tamanhoMatriz)

    if determinanteNulo(matriz):
        print('Essa matriz tem determinante nulo :))')
    else:
        print('Essa matriz não tem determinante nulo >>:((')
