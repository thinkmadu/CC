# %%
#Q1 - Faça um Programa que peça um número e então mostre a mensagem: O número informado foi [número]. 

entrada = int(input("Digite um número:"))
print("O número informado foi:", entrada)
# Out:
# Digite um número:5
# O número informado foi: 5

# %%
entrada = int(input("Insira um número:"))
entrada2 = int(input("Insira outro número:"))
soma = entrada + entrada2
print("O resultado da soma é:", soma)
# Out:
# Insira um número:5
# Insira outro número:7
# O resultado da soma é: 12

# %%
n1 = float(input("Insira a nota do 1º bimestre:"))
n2 = float(input("Insira a nota do 2º bimestre:"))
n3 = float(input("Insira a nota do 3º bimestre:"))
n4 = float(input("Insira a nota do 4º bimestre:"))

soma = n1 + n2 + n3 + n4
media = soma/4
print("Sua média é:", media)
# Out:
# Insira a nota do 1º bimestre:5
# Insira a nota do 2º bimestre:9
# Insira a nota do 3º bimestre:8
# Insira a nota do 4º bimestre:3
# Sua média é: 6.25

# %%
entrada = float(input("Insira o valor em metros:"))
metros = int(entrada * 100)

print(entrada,"m é",metros, "cm")
# Out:
# Insira o valor em metros:1.68
# 1.68 m é 168 cm

# %%
entrada = int(input("Qual o raio do círculo?"))
import math
math.pi
area = float(entrada * math.pi **2)
print("A área do círculo é:", area)
# Out:
# Qual o raio do círculo?5
# A área do círculo é: 49.34802200544679

# %%
base = float(input("Qual o tamanho da base do quadrado?"))
area = float(base **2)
resultado = float(area * 2)
print("O dobro da área do quadrado é:", resultado)
# Out:
# Qual o tamanho da base do quadrado?5
# O dobro da área do quadrado é: 50.0

# %%
ganho = float(input("Quanto você ganha por hora trabalhada?"))
hora = int(input("Quantas horas você trabalhou no mês?"))

resultado = ganho * hora
print("Nesse mês, o seu salário será R$", resultado)

# %%
entrada = int(input("Quantos ºF estão agora?"))
F = entrada - 32
celsius = int(5 * F / 9)

print("Agora está", celsius, "ºC")
# Out:
# Quantos ºF estão agora?82
# Agora está 27 ºC

# %%
entrada = int(input("Quantos ºC estão agora?"))
C = entrada * 9 / 5
F = int(C + 32)

print("Agora está", F, "ºF")
# Out:
# Quantos ºC estão agora?28
# Agora está 82 ºF

# %%
cotação = float(input("Qual a cotação do dólar hoje?"))
dólar = int(input("Quantos dólares você possui?"))

conversão = int(dólar * cotação)
print("Você possui R$", conversão, "em dólar")
# Out:
# Qual a cotação do dólar hoje?4.98
# Quantos dólares você possui?50
# Você possui R$ 249 em dólar

# %%
deposito = float(input("Quanto você deseja depositar?"))
rendimento = float(deposito * 0.007)
resultado = deposito + rendimento

print("Após 1 mês, seu dinheiro será R$", resultado)
# Out:
# Quanto você deseja depositar?100
# Após 1 mês, seu dinheiro será R$ 100.7

# %%
entrada = float(input("Quanto deu a compra?"))
prestações = float(entrada / 5)

print("Vão ser 5 prestações de R$", prestações)
# Out:
# Quanto deu a compra?40.45
# Vão ser 5 prestações de R$ 8.09

# %%
entrada = float(input("Quanto foi o custo do produto?"))
lucro = float(input("Qual a porcentagem de ganho que deseja obter?"))
lucro2 = float(lucro / 100)
resultado = float(entrada * lucro2)
resultado2 = resultado + entrada

print("O preço deve ser R$", resultado2)
# Out:
# Quanto foi o custo do produto?12
# Qual a porcentagem de ganho que deseja obter?15
# O preço deve ser R$ 13.8

# %%
entrada = float(input("Qual a distância percorrida?"))
gasolina = float(input("Quantos litros de gasolina foi consumido?"))
resultado = entrada / gasolina

print("Seu carro percorreu ", resultado, "km/litro")
# Out:
# Qual a distância percorrida?500
# Quantos litros de gasolina foi consumido?100
# Seu carro percorreu  5.0 km/litro

# %%
A = float(input("Qual o valor da variável A?"))
B = float(input("Qual o valor da variável B?"))
C = float(input("Qual o valor da variável C?"))

R = A ** 2 + B ** 2
S = B ** 2 + C ** 2
D = (R + S) / 2

print("O resultado da equação é:", D)
# Out:
# Qual o valor da variável A?2
# Qual o valor da variável B?5
# Qual o valor da variável C?10
# O resultado da equação é: 77.0

# %%
nome = input("Qual o seu nome?")
salariob = float(input("Digite o seu salário base:"))
venda = int(input("Quantas vendas você realizou?"))

comissao = float(0.15 * salariob)
comissao2 = int(comissao * vendas)
salarioR = float(salariob + comissao2)

print("Olá", nome)
print("Seu salário base é de R$"+ str(salariob), "mas graças as suas vendas seu salário mensal será de R$", int(salarioR))
# Out:
# Qual o seu nome?Maria
# Digite o seu salário base:1200
# Quantas vendas você realizou?20
# Olá Maria
# Seu salário base é de R$1200.0 mas graças as suas vendas seu salário mensal será de R$ 4800

# %%
inteiro1 = int(input("Digite um número inteiro:"))
inteiro2 = int(input("Digite outro número inteiro:"))
real = float(input("Digite um número real:"))

a = (inteiro1 **2) * inteiro2/2
b = (inteiro1) * 3 + real
c = real **3

print("O produto do dobro do primeiro com metade do segundo é:", a)
print("A soma do triplo do primeiro com o terceiro é:", b)
print("O terceiro elevado ao cubo é:", c)
# Out:
# Digite um número inteiro:2
# Digite outro número inteiro:4
# Digite um número real:1.5
# O produto do dobro do primeiro com metade do segundo é: 8.0
# A soma do triplo do primeiro com o terceiro é: 7.5
# O terceiro elevado ao cubo é: 3.375

# %%
altura = float(input("Qual a sua altura?"))
peso = float(input("Quanto você pesa?"))

imc = int((peso * altura) - 58)

print("Seu IMC é de", imc)
# Out:
# Qual a sua altura?1.68
# Quanto você pesa?52
# Seu IMC é de 29

# %%
tamanho = float(input("Quantos MB tem o arquivo?"))
internet = int(input("Qual a banda larga da sua internet?"))

MBPS = (tamanho / internet)
tempo = MBPS / 60

print("O arquivo será baixado em", tempo)
# Out:
# O arquivo será baixado em 0.016666666666666666

# %%
#Q20 - Ler dois valores para as variáveis A e B, e efetuar as trocas dos valores de forma que a variável A passe a possuir o valor da 
#variável B e a variável B passe a possuir o valor da variável A. Apresentar os valores trocados.

a = float(input('Insira um número: '))
b = float(input('Insira outro número: '))

aux = a
a = b
b = aux

print(a, b)
# Out:
# 35.0 20.0

# %% [markdown]
# Q21 - 21.Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu
# salário no referido mês, sabendo-se que são descontados 11% para o Imposto de Renda, 8% para o INSS e 5% para o sindicato, faça um
# programa que nos dê:
#
# a) salário bruto.
# b) quanto pagou ao INSS.
# c) quanto pagou ao sindicato.
# d) o salário líquido.
# e) calcule os descontos e o salário líquido, conforme a tabela abaixo:
# Salário Bruto : R$
# IR (11%) : R$
# INSS (8%) : R$
# Sindicato ( 5%) : R$
# Salário Liquido : R$
#
# Obs.: Salário Bruto - Descontos = Salário Líquido.

# %%
entrada = float(input('Valor por hora: '))
tempo = float(input('Horas trabalhadas: '))

salarioBruto = entrada * tempo
IR = 0.11 * salarioBruto
INSS = 0.08 * salarioBruto
sindicato = 0.05 * salarioBruto

salarioLiquido = salarioBruto - (IR + INSS + sindicato)

print('Seu salário bruto foi de R$', salarioBruto)
print('Seu salário líquido é de R$', salarioLiquido)
print('(-) IR (11%) R$', IR)
print('(-) INSS (8%) R$', INSS)
print('(-) Sindicato (5%) R$', sindicato)
# Out:
# Seu salário bruto foi de R$ 80.0
# Seu salário líquido é de R$ 60.8
# (-) IR (11%) R$ 8.8
# (-) INSS (8%) R$ 6.4
# (-) Sindicato (5%) R$ 4.0
