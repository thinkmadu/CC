# %% [markdown]
# Dupla: Maria Eduarda da Silva (matrícula: 221080163) e Lívia Nascimento (matrícula: )

# %% [markdown]
# 1. (5.0) Escreva uma função em Python para solucionar o seguinte problema: dadas 2 listas com n números entre 0 e 9, interpretadas como dois números inteiros de n dígitos, calcular uma lista que representa a somatória dos dois números.

# %%
lista1 = list(map(int, input("Digite os nº da 1ª lista: ").strip().split()))
lista2 = list(map(int, input("Digite os nº da 2ª lista: ").strip().split()))

def somaElementos(lista1,lista2):
    lista1.reverse()
    lista2.reverse()
    lista3 = list()
    transporte = 0

    lista1.append(0)
    lista2.append(0)
    
    while len(lista1) != len(lista2):
        if len(lista1) > len(lista2):
            lista2.append(0)
        
        else:
            lista1.append(0)

    for i in range (len(lista1)):
        soma = lista1[i] + lista2[i] + transporte
        transporte = soma // 10

        if soma > 9:
            novoNum = soma % 10
            lista3.append(novoNum)
        else:
            lista3.append(soma)
        
            
    lista3.reverse()
    return lista3

print(somaElementos(lista1,lista2))
# Out:
# [0, 2, 5, 8]

# %% [markdown]
# 2. (5.0) Faça uma função em Python que verifique a seguinte propriedade do determinante de uma matriz fornecida pelo usuário.
#
# “Se todos os elementos de uma linha ou coluna são iguais à zero,
# o determinante da matriz é nulo.”
#
# A função deve apresentar uma mensagem informando se o determinante da matriz fornecida é ou não igual a zero segundo a propriedade acima.

# %%
# os inputs das linhas vão ser separadas por espaços

def numIguais(lista):
    for i in lista:
        if i != 0:
            return False

    return True


def determinanteNulo(matriz):
    colunasMatriz = list()

    for linhas in matriz:
        if numIguais(linhas):
            return True        
        
    for index in range(len(matriz[0])):
        listaTemp = list()

        for linhas in matriz:
            listaTemp.append(linhas[index])
        
        colunasMatriz.append(listaTemp)
        listaTemp = list()
    
    for matriz in colunasMatriz:
        if numIguais(matriz):
            return True
    
    return False


def geradorMatriz(tamanho):
    matriz = list()

    for index, linha in enumerate(range(tamanho)):
        elementosLinha = list(map(int, input('Digite os elementos da {}ª linha: '.format(index + 1)).strip().split()))

        if len(elementosLinha) != tamanhoMatriz:
            print('A quantidade de nº informados não é compatível com a dimensão da matriz selecionada!')
        
        matriz.append(elementosLinha)

    return matriz


tamanhoMatriz = int(input('Digite a dimensão da matriz: '))

if tamanhoMatriz <= 0:
    raise Exception('Pô Kézia! A dimensão da matriz precisa ser um inteiro maior que 0!!!')
    
matriz = geradorMatriz(tamanhoMatriz)

if determinanteNulo(matriz):
    print('O determinante dessa matriz é nulo :))')
        
else:
    print('O determinante dessa matriz não é nulo >>:((')
# Out:
# O determinante dessa matriz é nulo :))

# %%
# os inputs das linhas vão ser separadas por espaços.
# madu style

def geradorMatriz(tamanho):
    matriz = list()

    for index, linha in enumerate(range(tamanho)):
        elementosLinha = list(map(int, input('Digite os elementos da {}ª linha: '.format(index + 1)).strip().split()))

        if len(elementosLinha) != tamanhoMatriz:
            print('A quantidade de nº informados não é compatível com a dimensão da matriz selecionada!')
        
        matriz.append(elementosLinha)

    return matriz


def numIguais(lista):
    for i in lista:
        if i != 0:
            return False
        else:
            return True


def determinanteNulo(matriz):
    colunasMatriz = list()

    for linhas in matriz:
        if numIguais(linhas):
            return True
        
    for index in range(len(matriz[0])):
        listaTemp = list()

        for linhas in matriz:
            listaTemp.append(linhas[index])
        
        colunasMatriz.append(listaTemp)
        listaTemp = list()
    
    for matriz in colunasMatriz:
        if numIguais(matriz):
            return True


tamanhoMatriz = int(input('Digite a dimensão da matriz: '))

if tamanhoMatriz <= 0:
    raise Exception('Pô Kézia! A dimensão da matriz precisa ser um inteiro maior que 0!!!')
    
matriz = geradorMatriz(tamanhoMatriz)

if determinanteNulo(matriz):
    print('O determinante dessa matriz é nulo :))')
else:
    print('O determinante dessa matriz não é nulo >>:((')
# Out:
# O determinante dessa matriz não é nulo >>:((
