# %% [markdown]
# 1.

# %%
num1 = float(input("Digite um número:"))
num2 = float(input("Digite outro número:"))

if num1 > num2:
  print(num1, "é o número maior")

elif num2 < num1:
  print(num2, "é o maior número.")

else:
  print("Os números são iguais.")
# Out:
# Digite um número:5
# Digite outro número:5
# Os números são iguais.

# %% [markdown]
# 2.

# %%
num = float(input("Digite um número:"))

if num > 0:
  print("Este número é positivo.")

elif num == 0:
  print("Este número é nulo.")

else:
  print("Este número é negativo.")
# Out:
# Digite um número:0
# Este número é nulo.

# %% [markdown]
# 3.

# %%
entrada = str(input("Digite o sexo:"))
m = str("m")
f = str("f")

if entrada == f:
  print(f, "é o sexo feminino.")

elif entrada == m:
  print(m, "é do sexo masculino")

else:
  print("Sexo inválido.")
# Out:
# Digite o sexo:f
# f é o sexo feminino.

# %% [markdown]
# 4.

# %%
n1 = float(input("Digite a 1ª nota parcial:"))
n2 = float(input("Digite a 2ª nota parcial:"))

media = (n1 + n2)/2

if media == 10:
  print("Aprovado com distinção!!!")

elif media > 7:
  print("Aprovado")

else:
  print("Reprovado :((")
# Out:
# Digite a 1ª nota parcial:10
# Digite a 2ª nota parcial:8
# Aprovado

# %% [markdown]
# 5.

# %%
num1 = float(input("Digite o 1º número:"))
num2 = float(input("Digite o 2º número:"))
num3 = float(input("Digite o 3º número:"))

maior = num1

if (num2 > maior):
  maior = num2

elif (num3 > maior):
  maior = num3
  print("maior número:", maior)

else:
  print("maior número:", maior)
# Out:
# Digite o 1º número:3
# Digite o 2º número:2
# Digite o 3º número:1
# maior número: 3.0

# %% [markdown]
# Solução que achei na internet pra esse problema, entretanto não tava dando certo com as minhas variáveis, então adaptei.

# %%
    primeiro = int(input('Primeiro numero: '))
    segundo  = int(input('Segundo numero : '))
    terceiro = int(input('Terceiro numero: '))

    maior = primeiro

    if (segundo > maior):
        maior = segundo
    if (terceiro > maior):
        maior = terceiro

    print('Maior: ',maior)
# Out:
# Primeiro numero: 3
# Segundo numero : 2
# Terceiro numero: 1
# Maior:  3

# %% [markdown]
# 6.

# %%
num1 = float(input("Digite o 1º número:"))
num2 = float(input("Digite o 2º número:"))
num3 = float(input("Digite o 3º número:"))

menor = num1

if (num2 < menor):
  menor = num2
  print("melhor preço:", menor)

elif (num3 < menor):
  menor = num3
  print("melhor preço:", menor)

else:
  print("melhor preço:", menor)
# Out:
# Digite o 1º número:20
# Digite o 2º número:15
# Digite o 3º número:30
# melhor preço: 15.0

# %% [markdown]
# 7.

# %%
turno = str(input("Qual o meu turno?"))
manhã = str('M')
tarde = str('T')
noite = str('N')

if turno == manhã:
  print("Bom dia, estudante da matutino!")

elif turno == tarde:
  print("Boa tarde, estudante da vespertino!")

elif turno == noite:
  print("Bom dia, estudante da noturno!")

else:
  print('Turno inválido')
# Out:
# Qual o meu turno?RU
# Turno inválido

# %% [markdown]
# 8.

# %%
salario = float(input('Qual o seu salário?'))

aj1 = 0.2
aj2 = 0.15
aj3 = 0.10
aj4 = 0.05

cond1 = 280
cond2 = 700
cond3 = 1500
con4 = (salario * aj4) + salario
if salario <= cond1:
  con1 = (salario * aj1) + salario
  print('Seu salário é de:',con1)

elif ((salario > cond1) and (>= cond2)):
    con2 = (salario * aj2) + salario
    print('Seu salário é de:', con2)

elif salario > 700:
  if salario <= 1500:
    con3 = (salario * aj3) + salario
    print('Seu salário é de:', con3)

elif salario <= 1500:
      con3 = (salario * aj3) + salario
      print('Seu salário é de:', con3)

else: 
  con4 = (salario * aj4) + salario
  print('Seu salário é de:', lol)

#tentativa falha
# Out:
#   File "<ipython-input-23-ce9f96cd5317>", line 16
#     elif ((salario > cond1) and (>= cond2)):
#                                   ^
# SyntaxError: invalid syntax

# %%
salario = float(input('Qual o seu salário?'))

aj1 = 0.2
aj2 = 0.15
aj3 = 0.10
aj4 = 0.05

limite1 = 280
limite2 = 700
limite3 = 1500

if salario <= limite1:
 calc1 = (salario * aj1) + salario
 print('Seu salário é de:', calc1)
 print('Salário antes do reajuste:', salario)
 print('Percentual de aumento: 20%')
 aumento_reais = salario * aj1
 print('Valor em reais do aumento {:.2f}'.format(aumento_reais))

elif salario > limite1 and salario <= limite2:
  calc2 = (salario * aj2) + salario
  print('Seu salário é de:', calc2)
  print('Salário antes do reajuste:', salario)
  print('Percentual de aumento: 15%')
  aumento_reais1 = salario * aj2
  print('Valor em reais do aumento {:.2f}'.format(aumento_reais1))

elif salario > limite2 and salario <= limite3:
  calc3 = (salario * aj3) + salario
  print('Seu salário é de:', calc3)
  print('Salário antes do reajuste:', salario)
  print('Percentual de aumento: 10%')
  aumento_reais2 = salario * aj3
  print('Valor em reais do aumento {:.2f}'.format(aumento_reais2))

else:
  calc4 = (salario * aj4) + salario
  print('Seu salário é de:', calc4)
  print('Salário antes do reajuste:', salario)
  print('Percentual de aumento: 5%')
  aumento_reais3 = salario * aj4
  print('Valor em reais do aumento {:.2f}'.format(aumento_reais3))

#2ª tentativa com ajuda da internet
# Out:
# Qual o seu salário?777
# Seu salário é de: 854.7
# Salário antes do reajuste: 777.0
# Percentual de aumento: 10%
# Valor em reais do aumento 77.70

# %% [markdown]
# 9.

# %%
ganho = float(input("Quanto você ganha por hora? "))
hora = int(input("Quantas horas você trabalhou esse mês? "))

salario = ganho * hora
inss = salario * 0.10
fgts = (salario * 0.11)
ir1 = (salario * 0.05)
ir2 = (salario * 0.10)
ir3 = (salario * 0.20)

if salario <= 900:
  descontos = salario - (salario * inss)
  inss2 = salario * inss
  total_desconto1 = salario * inss
  print('Salário bruto {} * {}:            R${:.2f}'.format(ganho, hora, salario))
  print('(-) IR:                              -------')
  print('(-) INSS (10%):                      R${:.2f}'.format(inss2))
  print('FGTS:                                R${:.2f}'.format(fgts))
  print('TOTAL DE DESCONTOS:                  R${:.2f}'.format(total_desconto1))

elif salario > 900 and salario <= 1500:
  salario_liquido0 = salario - inss ()
  total_desconto2 = (inss + ir1)
  salario_liquido1 = salario - total_desconto2
  print('Salário bruto {} * {}:            R${:.2f}'.format(ganho, hora, salario))
  print('(-) IR:                               R${:.2f}'.format(ir1))
  print('(-) INSS (10%):                      R${:.2f}'.format(inss))
  print('FGTS:                                R${:.2f}'.format(fgts))
  print('TOTAL DE DESCONTOS:                  R${:.2f}'.format(total_desconto2))
  print('SALÁRIO LÍQUIDO:                     R${:.2F}'.format(salario_liquido1))

elif salario >= 1500 and salario <= 2500:
  salario_liquido2 = salario - (inss + ir2)
  total_descontos = inss + ir2
  print('Salário bruto {} * {}:            R${:.2f}'.format(ganho, hora, salario))
  print('(-) IR:                              R${:.2f}'.format(ir2))
  print('(-) INSS (10%):                      R${:.2f}'.format(inss))
  print('FGTS:                                R${:.2f}'.format(fgts))
  print('TOTAL DE DESCONTOS:                  R${:.2f}'.format(total_descontos))
  print('SALÁRIO LÍQUIDO:                    R${:.2F}'.format(salario_liquido2))

else:
  salario_liquido3 = salario - (inss + ir3)
  total_descontos = inss + ir3
  print('Salário bruto {} * {}:          R${:.2f}'.format(ganho, hora, salario))
  print('(-) IR:                              R${:.2f}'.format(ir3))
  print('(-) INSS (10%):                      R${:.2f}'.format(inss))
  print('FGTS:                                R${:.2f}'.format(fgts))
  print('TOTAL DE DESCONTOS:                  R${:.2f}'.format(total_descontos))
  print('SALÁRIO LÍQUIDO:                     R${:.2F}'.format(salario_liquido3))
# Out:
# Quanto você ganha por hora? 10
# Quantas horas você trabalhou esse mês? 1000
# Salário bruto 10.0 * 1000:          R$10000.00
# (-) IR:                              R$2000.00
# (-) INSS (10%):                      R$1000.00
# FGTS:                                R$1100.00
# TOTAL DE DESCONTOS:                  R$3000.00
# SALÁRIO LÍQUIDO:                     R$7000.00

# %% [markdown]
# 10.

# %%
entrada = int(input('Digite o nº do dia da semana: '))

dom = int('1') 
seg = int('2')
ter = int('3')
qua = int('4')
qui = int('5')
sex = int('6')
sab = int('7')

if entrada == dom:
  print('O dia da semana é: DOMINGO ')

elif entrada == seg:
  print('O dia da semana é: SEGUNDA')

elif entrada == ter:
  print('O dia da semana é: TERÇA')

elif entrada == qua:
  print('O dia da semana é: QUARTA')

elif entrada == qui:
  print('O dia da semana é: QUINTA')

elif entrada == sex:
  print('O dia da semana é: SEXTA')

elif entrada == sab:
  print('O dia da semana é: SÁBADO')

else:
  print('Número inválido')
# Out:
# Digite o nº do dia da semana: 0
# Número inválido

# %% [markdown]
# 11.

# %%
n1 = float(input('Digite sua 1ª nota:'))
n2 = float(input('Digite sua 2ª nota:'))

media = (n1 + n2) / 2

if media >= 9 and media <= 10:
  print('Sua média é de {:.2f}, portanto sua nota é A' .format(media))
  print('Aluno APROVADO')

elif media < 9 and media >= 7.5:
  print('Sua média é de {:.2f}, portanto sua nota é B' .format(media))
  print('Aluno APROVADO')

elif media < 7.5 and media >= 6:
  print('Sua média é de {:.2f}, portanto sua nota é C' .format(media))
  print('Aluno APROVADO')

elif media < 6 and media >= 4:
  print('Sua média é de {:.2f}, portanto sua nota é D' .format(media))
  print('Aluno REPROVADO')

else:
  print('Sua média é de {:.2f}, portanto sua nota é E' .format(media))
  print('Aluno REPROVADO')
# Out:
# Digite sua 1ª nota:10
# Digite sua 2ª nota:2
# Sua média é de 6.00, portanto sua nota é C
# Aluno APROVADO

# %% [markdown]
# 12.

# %%
lado1 = float(input('Digite o 1º valor:'))
lado2 = float(input('Digite o 2º valor:'))
lado3 = float(input('Digite o 3º valor:'))

if lado1 + lado2 < lado3 or lado2 + lado3 < lado1 or lado1 + lado3 < lado3:
  print('Valores inválidos, isso não é um triângulo.')

elif (lado1 == lado2) and (lado2 == lado3):
  print('Isso é um triângulo equilátero')

elif (lado1 == lado2) or (lado2 == lado3) or (lado1 == lado3):
  print('Isso é um triângulo isósceles.')

else:
  print('Isso é um triângulo escaleno')
# Out:
# Digite o 1º valor:5
# Digite o 2º valor:5
# Digite o 3º valor:5
# Isso é um triângulo equilátero

# %% [markdown]
# 13.

# %%
a = float(input("valor a: "))

if a == 0:
    print("Não é do segundo grau")

else:
    b = float(input("valor b: "))
    c = float(input("valor c: "))
    
    delta = b**2 - 4*a*c
    
    if delta < 0:
        print("Não há raízes reais")
    elif delta == 0:
        raiz = -b/(2*a)
        print(raiz)
    else:
        x1 = (-b + delta ** 0.5)/(2*a)
        x2 = (-b - delta ** 0.5)/(2*a)
        print(x1,x2)
# Out:
# valor a: 5
# valor b: 24
# valor c: 2
# -0.0848326194419549 -4.715167380558045

# %% [markdown]
# 14.

# %%
ano = int(input('Digite um ano:'))

if (ano % 4 == 0 and ano % 100 !=0) or (ano % 400 == 0):
  print('{} é um ano bissexto.'.format(ano))

else:
  print('{} não é um ano bissexto.'.format(ano))

#Procurei ajuda na internet
# Out:
# Digite um ano:2000
# 2000 é um ano bissexto.

# %%
#VERSÃO COM IMPORTAÇÃO DE BIBLIOTECAS

from calendar import isleap

ano = int(input('Digite um ano:'))

if isleap(ano):
    print('É bissexto')
else:
    print('Não é bissexto')
# Out:
# Digite um ano:1900
# Não é bissexto

# %% [markdown]
# 15.

# %%
n1 = float(input('Digite sua 1ª nota:'))
n2 = float(input('Digite sua 2ª nota:'))
n3 = float(input('Digite sua 3ª nota:'))

media = (n1 + n2 + n3)/ 3

if media == 10:
  print('Aprovado com distinção com média de {}'.format(media))

elif media >= 7:
  print('Aluno aprovado com média de {}'.format(media))

else:
  print('Aluno reprovado com média de {}'.format(media))
# Out:
# Digite sua 1ª nota:0
# Digite sua 2ª nota:0
# Digite sua 3ª nota:0
# Aluno reprovado com média de 0.0

# %% [markdown]
# 16. Faça um Programa para um caixa eletrônico. O programa deverá perguntar ao usuário a valor do saque e depois informar quantas notas de cada valor serão fornecidas. As notas disponíveis serão as de 1, 5, 10, 50 e 100 reais. O valor mínimo é de 10 reais e o máximo de 600 reais. O programa não deve se preocupar com a quantidade de notas existentes na máquina.
# - Exemplo 1: Para sacar a quantia de 256 reais, o programa fornece duas notas de 100, uma nota de 50, uma nota de 5 e uma nota de 1;
# - Exemplo 2: Para sacar a quantia de 399 reais, o programa fornece três notas de 100, uma nota de 50, quatro notas de 10, uma nota de 5 e quatro notas de 1.

# %%
valorSaque = int(input('Digite a quantia a ser sacada: '))
nota100 = int(100)
nota50 = int(50)
nota10 = int(10)
nota5 = int(5)

while valorSaque >= 10:
    if valorSaque >= 10 and valorSaque <= 600:
        op1 = (valorSaque // nota100)
        op2 = (valorSaque % nota100) // nota50
        op3 = (valorSaque % nota50) // nota10
        op3 = (valorSaque % nota10) // nota5
        op4 = (valorSaque % nota5)
        print(op1, op2, op3, op4)
    else:
        print('Valor inválido')
    valorSaque = int(input('Digite a quantia a ser sacada: '))
# Out:
# 2 0 0 0
# 5 0 0 0
# 3 1 0 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\think\OneDrive\Documentos\Ciência da computação 2022.1\Algoritmos\Phyton\Lista III - algoritmos.ipynb Cell 36' in <cell line: 7>()
#      <a href='vscode-notebook-cell:/c%3A/Users/think/OneDrive/Documentos/Ci%C3%AAncia%20da%20computa%C3%A7%C3%A3o%202022.1/Algoritmos/Phyton/Lista%20III%20-%20algoritmos.ipynb#ch0000035?line=14'>15</a> else:
#      <a href='vscode-notebook-cell:/c%3A/Users/think/OneDrive/Documentos/Ci%C3%AAncia%20da%20computa%C3%A7%C3%A3o%202022.1/Algoritmos/Phyton/Lista%20III%20-%20algoritmos.ipynb#ch0000035?line=15'>16</a>     print('Valor inválido')
# ...

# %% [markdown]
# 17.

# %%
numero = int(input("Informe o número: "))

if numero > 0:
    print("positivo")

elif numero == 0 :
    print("neutro")
    
else:
    print("negativo")

# %% [markdown]
# 18.

# %%
n1 = float(input('Digite um número: '))
n2 = float(input('Digite um número: '))
operação = str(input('Qual operação você deseja fazer?'))

soma = str('+')
subtração = str('-')
divisão = str('/')
multiplicaçao = str('*')

if operação == soma:
  resultado = n1 + n2
  print('O resultado da soma é {}'.format(resultado))

elif operação == subtração:
  resultado = n1 - n2
  print('O resultado da subtração é {}'.format(resultado))

elif operação == divisão:
  resultado = n1 / n2
  print('O resultado da divisão é {:.2f}'.format(resultado))

elif operação == multiplicaçao:
  resultado = n1 * n2
  print('O resultado da multiplicação é {}'.format(resultado))

else:
  print('Operação inválida.')
# Out:
# Digite um número: 5
# Digite um número: 9
# Qual operação você deseja fazer?-
# O resultado da subtração é -4.0

# %% [markdown]
# 19.

# %%
q1 = int(input('Telefonou para a vítima? 0 para não e 1 para sim: '))
q2 = int(input('Esteve no local do crime? 0 para não e 1 para sim: '))
q3 = int(input('Mora perto da vítima? 0 para não e 1 para sim: '))
q4 = int(input('Devia para a vítima? 0 para não e 1 para sim: '))
q5 = int(input('Já trabalhou com a vítima? 0 para não e 1 para sim: '))

soma = q1 + q2 + q3 + q4 + q5

if soma == 0:
  print('Você é inocente <3')

elif soma == 5 :
  print('Você é o ASSASINO!')

elif soma >= 3 or soma == 4:
  print('Você é cúmplice!')

elif soma > 0 or soma <= 2:
  print('Você é suspeito...')

else:
  print('Responda corretamente!!! ')
# Out:
# Telefonou para a vítima? 0 para não e 1 para sim: 0
# Esteve no local do crime? 0 para não e 1 para sim: 0
# Mora perto da vítima? 0 para não e 1 para sim: 0
# Devia para a vítima? 0 para não e 1 para sim: 0
# Já trabalhou com a vítima? 0 para não e 1 para sim: 0
# Você é inocente <3

# %% [markdown]
# 20.

# %%
litro = int(input('Quantos litros de gasolina você comprou?' ))
tipo = str(input('Que tipo de combustível você comprou? '))

gasolina = ('G')
alcool = ('A')

preço1 = 2.50
preço2 = 1.90

if tipo == gasolina:
  if litro <= 20:
    valor0 = preço1 * litro
    desconto0 = valor0 - (litro * 0.04)
    print('Você deve pagar R${}'.format(desconto0))
  
  else:
    valor1 = preço1 * litro
    desconto1 = valor1 - (litro * 0.06)
    print('Você deve pagar R${}'.format(desconto1))

elif tipo == alcool:
  if litro <= 20:
    valor2 = preço2 * litro
    desconto2 = valor2 - (litro * 0.03)
    print('Você deve pagar R${}'.format(desconto2))



  else:
    valor3 = preço2 * litro
    desconto3 = valor3 - (litro * 0.05)
    print('Você deve pagar R${}'.format(desconto3))

else:
  print('Dados inválidos')
# Out:
# Quantos litros de gasolina você comprou?10
# Que tipo de combustível você comprou? A
# Você deve pagar R$18.7

# %% [markdown]
# 21.

# %%
morango = float(input('Quantos kg de morango você comprou? '))
maça = float(input('Quantos kg de maçã você comprou? '))

valor_morango1 = 2.50
valor_morango2 = 2.20
valor_maça1 = 1.80
valor_maça2 = 1.50
 
if morango + maça > 8:
  preço_frutas1 = (morango * valor_morango2) + (maça * valor_maça2)
  desconto = preço_frutas1 - (preço_frutas1 * 0.10)

  if preço_frutas1 > 25:
    novodesconto = desconto - (desconto * 0.10)
    print('O valor a ser pago é de R${:.2f}'.format(novodesconto))

  else:
    print('O valor a ser pago é de R${}'.format(desconto))

else:
  preço_frutas2 = (morango * valor_morango1) + (maça * valor_maça1)
  print('O valor a ser pago é de R${}'.format(preço_frutas2))
# Out:
# Quantos kg de morango você comprou? 8
# Quantos kg de maçã você comprou? 8
# O valor a ser pago é de R$23.98

# %% [markdown]
# 22.Elabore um algoritmo que dada a idade de um nadador classifica-o em uma das seguintes categorias:  infantil A = 5 - 7 anos; infantil B = 8-10 anos; juvenil A = 11-13 anos; juvenil B = 14-17 anos; adulto = maiores de 18 anos.

# %%
idade = int(input('Qual a sua idade? '))

if idade <= 7 :
  print('Nadador Infantil A')

elif idade >= 8 and idade <= 10:
  print('Nadador Infantil B')

elif idade >= 11 and idade <= 13:
  print('Nadador Juvenil A')

elif idade >= 14 and idade <= 17:
  print('Nadador Juvenil B')

else:
  print('Nadador Adulto')
# Out:
# Qual a sua idade? 20
# Nadador Adulto

# %% [markdown]
# 23.Tendo como dados de entrada a altura e o sexo de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas: para homens: (72.7*h) – 58 e para mulheres: (62.1*h) - 44.7 (h = altura)

# %%
altura = float(input('Qual a sua altura em m? '))
sexo = str(input('Qual o seu gênero? '))

masculino = str('masculino') or ('M') or ('m') or ('Masculino')
feminino = str('feminino') or ('F') or ('f') or ('Feminino')

if sexo == masculino:
  peso_m = (72.2 * altura) - 58
  print('O seu peso ideal é {:.2f}'.format(peso_m))

elif sexo == feminino:
  peso_f = (62.1 * altura) - 44.7
  print('O seu peso ideal é {:.2f}'.format(peso_f))

else:
  print('Dados inválidos!')
