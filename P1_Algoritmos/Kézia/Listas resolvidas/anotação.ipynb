# %% [markdown]
# - usar listas para armazenar as matrizes
# - A = [[1,2,3],[4,5,6],[7,8,9]]
#       linha0   linha1
#
# - listas dentro de listas são matrizes.
# A [0]linha [0]posição = 1
#
# - posição na lista | elemento dentro da lista (que fica dentro da lista)
#
# # as matrizes servem pra armazenar os pixels de uma imagem
#
# [0] * 3 cira lista com 3 0 e com o append adiciono a lista de 0 criadas em outra lista
# - append: representa 1 linha
# - listas: colunas
